# %%
# Imports
import numpy as np
import pandas as pd

from pandas_datareader import data as pdr
import riskfolio as rp
import yfinance as yf
yf.pdr_override()

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
def price():
    df = pd.DataFrame()
    for i in assets:
        raw = pdr.get_data_yahoo(i, start=start, end=end)['Adj Close']
        raw.name = i
        
        df = pd.concat([df, raw], axis = 1)
    return df
    
# 회사 요약 정보
def info(ticker_df):
    df_info = ticker_df.info
    return df_info

# 회사 배당, 분할 정보
def action(ticker_df):
    df_data = ticker_df.actions
    return df_data
    
# 회사 재무제표
def financials(ticker_df):
    df_finance = ticker_df.financials
    return df_finance
    
# 주주정보
def holders(ticker_df):
    df_holder = ticker_df.major_holders
    return df_holder

# 대차 대조표
def balance(ticker_df):
    df_balance = ticker_df.balance_sheet
    return df_balance

# 현금흐름표
def cashflow(ticker_df):
    df_cashflow = ticker_df.cashflow
    return df_cashflow

# 기업실적
def earnings(ticker_df):
    df_earnings = ticker_df.earnings
    return df_earnings

def portfolio():
    df = price()
    Y = df[assets].pct_change().dropna()

# %% [markdown]
# ### 초기 세팅
# #### 2001-01-01 ~ 2022-01-01까지 자료 사용
# #### stocks = 주식(현재는 무작위로), bonds = 채권(마찬가지로 무작위로)

# %%
# 초기 세팅
start = '2001-01-01'
end = '2022-01-01'
stocks = ["005930.KS", "000270.KS", "000660.KS","035720.KS"]
bonds = ['122260.KS', '114260.KS']
# 122260.KS (1년물 채권)
# 114260.KS (3년물 채권)
# 397420.KS (5년물 채권)
assets = stocks + bonds

df = price()
Y = df[assets].pct_change().dropna()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
Y.columns = list(info(yf.Ticker(i))['shortName'] for i in Y.columns)

# %% [markdown]
# ### Riskfolio 툴을 활용하여 6개의 자산을 포함한 포트폴리오 중 최적의 포트폴리오 발견(아래 코드는 Sharpe Ratio를 사용

# %%
model = 'Classic' # Model은 BL (Black Litterman) OR FM (Factor Model)
rm = 'MV' # Risk Measure가 사용됨 (지금은 분산 사용)
obj = 'Sharpe' # 샤프를 구하려고 함. MinRisk, MaxRet, Utility 가능
hist = True # 역사적 시나리오 사용
rf = 0 # Risk free rate은 0으로 가정
l = 0 # Risk aversion factor(Util일때만 사용 가능)

port = rp.Portfolio(returns = Y)
pd.options.display.float_format = '{:.4%}'.format    

method_mu = 'hist' # Expected returns based on historical data.
method_cov = 'hist' # Covariance matrix based on historical data.
port.assets_stats(method_mu = method_mu, method_cov = method_cov, d = 0.94)

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)
w.T
# Out:
#          SamsungElec  KIA CORP.  SK hynix    Kakao  KOSEF MSB  KODEX TBOND
# weights     12.8334%   10.1806%   4.1328% 12.0095%   31.7868%     29.0569%

# %%
ax = rp.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                height=6, width=10, ax=None)

# %%
points = 50 # Frontier에 있는 포인트의 수
frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
label = 'Max Risk Adjusted Return Portfolio'
mu = port.mu
cov = port.cov
returns = port.returns

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                rf=rf, alpha=0.05, cmap='viridis', w=w, label=label,
                marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
nav=port.nav

ax = rp.plot_drawdown(nav=nav, w=w, alpha=0.05, height=8, width=10, ax=None)

# %%
ax = rp.plot_table(returns=Y, w=w, MAR=0, alpha=0.05, ax=None)

# %% [markdown]
# ### Ward 연결법 & 스피어만으로 주식과 채권이 차이가 있는지 확인
# #### -> 유의미한 차이가 있다는 걸 알 수 있음.

# %%
ax = rp.plot_dendrogram(returns=Y, codependence='spearman',
                        linkage='ward', k=None, max_k=5,
                        leaf_order=True, ax=None)

# %%
ax = rp.plot_network(returns=Y, codependence="pearson",
                     linkage="ward", k=None, max_k=3,
                     alpha_tail=0.05, leaf_order=True,
                     kind='spring', ax=None)

# %%
rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']
w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
w_s.columns = rms
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_1a13e_row0_col0 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_1a13e_row0_col1, #T_1a13e_row0_col3, #T_1a13e_row3_col1, #T_1a13e_row3_col3 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_1a13e_row0_col2 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_1a13e_row0_col4 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_1a13e_row0_col5, #T_1a13e_row1_col11, #T_1a13e_row3_col10 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_1a13e_row0_col6 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_1a13e_row0_col7 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_1a13e_row0_col8, #T_1a13e_row1_col5 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_1a13e_row0_col9, #T_1a13e_row0_col11 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_1a13e_row0_col10 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_1a13e_row0_col12 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_1a13e_row1_col0 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_1a13e_row1_col1, #T_1a13e_row1_col3, #T_1a13e_row3_col11 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_1a13e_row1_col2 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_1a13e_row1_col4 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_1a13e_row1_col6, #T_1a13e_row1_col7, #T_1a13e_row1_col8, #T_1a13e_row2_col0, #T_1a13e_row2_col1, #T_1a13e_row2_col2, #T_1a13e_row2_col3, #T_1a13e_row2_col4, #T_1a13e_row2_col5, #T_1a13e_row2_col9, #T_1a13e_row2_col10, #T_1a13e_row2_col11, #T_1a13e_row2_col12, #T_1a13e_row5_col7 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1a13e_row1_col9 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_1a13e_row1_col10 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_1a13e_row1_col12, #T_1a13e_row2_col8 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_1a13e_row2_col6, #T_1a13e_row3_col8, #T_1a13e_row4_col9 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_1a13e_row2_col7 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_1a13e_row3_col0 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_1a13e_row3_col2 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_1a13e_row3_col4 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_1a13e_row3_col5 {
#   background-color: #f2fab5;
#   color: #000000;
# }
# #T_1a13e_row3_col6 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_1a13e_row3_col7 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_1a13e_row3_col9 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_1a13e_row3_col12 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# #T_1a13e_row4_col0, #T_1a13e_row4_col6, #T_1a13e_row4_col7, #T_1a13e_row4_col8, #T_1a13e_row5_col1, #T_1a13e_row5_col2, #T_1a13e_row5_col3, #T_1a13e_row5_col4, #T_1a13e_row5_col5, #T_1a13e_row5_col9, #T_1a13e_row5_col10, #T_1a13e_row5_col11, #T_1a13e_row5_col12 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_1a13e_row4_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_1a13e_row4_col2 {
#   background-color: #016937;
#   color: #f1f1f1;
# }
# #T_1a13e_row4_col3 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_1a13e_row4_col4 {
#   background-color: #005f34;
#   color: #f1f1f1;
# }
# #T_1a13e_row4_col5 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_1a13e_row4_col10 {
#   background-color: #197c40;
#   color: #f1f1f1;
# }
# #T_1a13e_row4_col11 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_1a13e_row4_col12 {
#   background-color: #00532f;
#   color: #f1f1f1;
# }
# #T_1a13e_row5_col0 {
#   background-color: #006034;
#   color: #f1f1f1;
# }
# #T_1a13e_row5_col6 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_1a13e_row5_col8 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a13e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MV</th>
#       <th class="col_heading level0 col1" >MAD</th>
#       <th class="col_heading level0 col2" >MSV</th>
#       <th class="col_heading level0 col3" >FLPM</th>
#       <th class="col_heading level0 col4" >SLPM</th>
#       <th class="col_heading level0 col5" >CVaR</th>
#       <th class="col_heading level0 col6" >EVaR</th>
#       <th class="col_heading level0 col7" >WR</th>
#       <th class="col_heading level0 col8" >MDD</th>
#       <th class="col_heading level0 col9" >ADD</th>
#       <th class="col_heading level0 col10" >CDaR</th>
#       <th class="col_heading level0 col11" >UCI</th>
#       <th class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a13e_level0_row0" class="row_heading level0 row0" >SamsungElec</th>
#       <td id="T_1a13e_row0_col0" class="data row0 col0" >12.83%</td>
#       <td id="T_1a13e_row0_col1" class="data row0 col1" >3.42%</td>
#       <td id="T_1a13e_row0_col2" class="data row0 col2" >11.60%</td>
#       <td id="T_1a13e_row0_col3" class="data row0 col3" >3.34%</td>
#       <td id="T_1a13e_row0_col4" class="data row0 col4" >11.72%</td>
#       <td id="T_1a13e_row0_col5" class="data row0 col5" >7.65%</td>
#       <td id="T_1a13e_row0_col6" class="data row0 col6" >14.63%</td>
#       <td id="T_1a13e_row0_col7" class="data row0 col7" >10.73%</td>
#       <td id="T_1a13e_row0_col8" class="data row0 col8" >3.97%</td>
#       <td id="T_1a13e_row0_col9" class="data row0 col9" >9.77%</td>
#       <td id="T_1a13e_row0_col10" class="data row0 col10" >10.13%</td>
#       <td id="T_1a13e_row0_col11" class="data row0 col11" >9.24%</td>
#       <td id="T_1a13e_row0_col12" class="data row0 col12" >9.91%</td>
#     </tr>
#     <tr>
#       <th id="T_1a13e_level0_row1" class="row_heading level0 row1" >KIA CORP.</th>
#       <td id="T_1a13e_row1_col0" class="data row1 col0" >10.18%</td>
#       <td id="T_1a13e_row1_col1" class="data row1 col1" >3.06%</td>
#       <td id="T_1a13e_row1_col2" class="data row1 col2" >9.42%</td>
#       <td id="T_1a13e_row1_col3" class="data row1 col3" >3.11%</td>
#       <td id="T_1a13e_row1_col4" class="data row1 col4" >9.45%</td>
#       <td id="T_1a13e_row1_col5" class="data row1 col5" >6.67%</td>
#       <td id="T_1a13e_row1_col6" class="data row1 col6" >1.25%</td>
#       <td id="T_1a13e_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_1a13e_row1_col8" class="data row1 col8" >0.14%</td>
#       <td id="T_1a13e_row1_col9" class="data row1 col9" >8.54%</td>
#       <td id="T_1a13e_row1_col10" class="data row1 col10" >7.87%</td>
#       <td id="T_1a13e_row1_col11" class="data row1 col11" >8.55%</td>
#       <td id="T_1a13e_row1_col12" class="data row1 col12" >2.12%</td>
#     </tr>
#     <tr>
#       <th id="T_1a13e_level0_row2" class="row_heading level0 row2" >SK hynix</th>
#       <td id="T_1a13e_row2_col0" class="data row2 col0" >4.13%</td>
#       <td id="T_1a13e_row2_col1" class="data row2 col1" >1.21%</td>
#       <td id="T_1a13e_row2_col2" class="data row2 col2" >3.91%</td>
#       <td id="T_1a13e_row2_col3" class="data row2 col3" >1.21%</td>
#       <td id="T_1a13e_row2_col4" class="data row2 col4" >3.97%</td>
#       <td id="T_1a13e_row2_col5" class="data row2 col5" >3.84%</td>
#       <td id="T_1a13e_row2_col6" class="data row2 col6" >5.90%</td>
#       <td id="T_1a13e_row2_col7" class="data row2 col7" >9.34%</td>
#       <td id="T_1a13e_row2_col8" class="data row2 col8" >0.81%</td>
#       <td id="T_1a13e_row2_col9" class="data row2 col9" >3.52%</td>
#       <td id="T_1a13e_row2_col10" class="data row2 col10" >1.89%</td>
#       <td id="T_1a13e_row2_col11" class="data row2 col11" >3.31%</td>
#       <td id="T_1a13e_row2_col12" class="data row2 col12" >1.64%</td>
#     </tr>
#     <tr>
#       <th id="T_1a13e_level0_row3" class="row_heading level0 row3" >Kakao</th>
#       <td id="T_1a13e_row3_col0" class="data row3 col0" >12.01%</td>
#       <td id="T_1a13e_row3_col1" class="data row3 col1" >3.26%</td>
#       <td id="T_1a13e_row3_col2" class="data row3 col2" >13.16%</td>
#       <td id="T_1a13e_row3_col3" class="data row3 col3" >3.31%</td>
#       <td id="T_1a13e_row3_col4" class="data row3 col4" >13.37%</td>
#       <td id="T_1a13e_row3_col5" class="data row3 col5" >9.85%</td>
#       <td id="T_1a13e_row3_col6" class="data row3 col6" >

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
