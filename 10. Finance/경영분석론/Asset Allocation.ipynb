# %% [markdown]
# # Coresatellite
# ## the benefits of index funds + actively managed funds
# ### 1. Reducing reliance on 'picking winners' or chasing fund manager returns
# ### 2. Providing greater portfolio diversification
# ### 3. Potentially improving after-tax returns by taking maximum advantage of capital gains discounts
# ### 4. Reducing overall fund management and transaction costs

# %% [markdown]
# ### 장점
# #### Competitive long-term performance
# #### Portfolio diversification
# #### Reduced key person risk

# %%
import numpy as np
import pandas as pd
import yfinance as yf # 야후 바이낸스의 차트의 주가 정보를 가져옴.
import warnings

import riskfolio as rp
import matplotlib.pyplot as plt
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\Administrator\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
warnings.filterwarnings("ignore") # 경고 메시지 무시
pd.options.display.float_format = '{:.4%}'.format # 실수 x를 받아 소수점 넷째자리까지만 표현

start = '2015-01-01'
end = '2019-12-30'

assets = ['VZ','042700.KS','005930.KS','006400.KS']
assets.sort()

data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets

Y = data[assets].pct_change().dropna()

model = 'Classic' # Model은 BL (Black Litterman) OR FM (Factor Model)
rm = 'MV' # Risk Measure가 사용됨 (지금은 분산 사용)
obj = 'Sharpe' # 샤프를 구하려고 함. MinRisk, MaxRet, Utility 가능
hist = True # 역사적 시나리오 사용
rf = 0 # Risk free rate은 0으로 가정
l = 0 # Risk aversion factor(Util일때만 사용 가능)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
port = rp.Portfolio(returns = Y)

method_mu = 'hist' # Expected returns based on historical data.
method_cov = 'hist' # Covariance matrix based on historical data.

port.assets_stats(method_mu = method_mu, method_cov = method_cov, d = 0.94)

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)
display(w.T)
# Out:
#          005930.KS  006400.KS  042700.KS       VZ
# weights   32.8385%   11.8994%    5.4883% 49.7738%

# %%
ax = rp.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)

# %%
points = 50 # Frontier에 있는 포인트의 수
frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)    
display(frontier.T.head())
# Out:
#    005930.KS  006400.KS  042700.KS       VZ
# 0   22.8027%    7.6665%    6.9002% 62.6306%
# 1   31.9918%   11.5425%    5.6075% 50.8582%
# 2   35.9114%   13.1960%    5.0561% 45.8366%
# 3   38.9953%   14.4967%    4.6225% 41.8855%
# 4   41.6581%   15.6200%    4.2480% 38.4739%

# %%
label = 'Max Risk Adjusted Return Portfolio'
mu = port.mu
cov = port.cov
returns = port.returns

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                  rf=rf, alpha=0.05, cmap='viridis', w=w, label=label,
                  marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']
w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
w_s.columns = rms
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_61ff8_row0_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col1 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col2, #T_61ff8_row0_col4 {
#   background-color: #56b568;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col3 {
#   background-color: #62bb6e;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col5 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col6 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col7 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_61ff8_row0_col8 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_61ff8_row0_col9 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col10 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_61ff8_row0_col11 {
#   background-color: #39a056;
#   color: #f1f1f1;
# }
# #T_61ff8_row0_col12 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_61ff8_row1_col0 {
#   background-color: #f2fab5;
#   color: #000000;
# }
# #T_61ff8_row1_col1 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_61ff8_row1_col2 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_61ff8_row1_col3 {
#   background-color: #f7fcbc;
#   color: #000000;
# }
# #T_61ff8_row1_col4 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_61ff8_row1_col5 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_61ff8_row1_col6 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_61ff8_row1_col7 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_61ff8_row1_col8 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_61ff8_row1_col9 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_61ff8_row1_col10, #T_61ff8_row1_col12, #T_61ff8_row2_col0, #T_61ff8_row2_col1, #T_61ff8_row2_col2, #T_61ff8_row2_col3, #T_61ff8_row2_col4, #T_61ff8_row2_col5, #T_61ff8_row2_col6, #T_61ff8_row2_col7, #T_61ff8_row2_col8, #T_61ff8_row2_col9, #T_61ff8_row2_col10, #T_61ff8_row2_col11, #T_61ff8_row2_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_61ff8_row1_col11 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_61ff8_row3_col0, #T_61ff8_row3_col1, #T_61ff8_row3_col2, #T_61ff8_row3_col3, #T_61ff8_row3_col4, #T_61ff8_row3_col5, #T_61ff8_row3_col6, #T_61ff8_row3_col7, #T_61ff8_row3_col8, #T_61ff8_row3_col9, #T_61ff8_row3_col10, #T_61ff8_row3_col11, #T_61ff8_row3_col12 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_61ff8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61ff8_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_61ff8_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_61ff8_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_61ff8_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_61ff8_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_61ff8_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_61ff8_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_61ff8_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_61ff8_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_61ff8_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_61ff8_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_61ff8_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_61ff8_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61ff8_level0_row0" class="row_heading level0 row0" >005930.KS</th>
#       <td id="T_61ff8_row0_col0" class="data row0 col0" >32.84%</td>
#       <td id="T_61ff8_row0_col1" class="data row0 col1" >30.99%</td>
#       <td id="T_61ff8_row0_col2" class="data row0 col2" >31.79%</td>
#       <td id="T_61ff8_row0_col3" class="data row0 col3" >30.99%</td>
#       <td id="T_61ff8_row0_col4" class="data row0 col4" >31.81%</td>
#       <td id="T_61ff8_row0_col5" class="data row0 col5" >36.06%</td>
#       <td id="T_61ff8_row0_col6" class="data row0 col6" >32.18%</td>
#       <td id="T_61ff8_row0_col7" class="data row0 col7" >14.97%</td>
#       <td id="T_61ff8_row0_col8" class="data row0 col8" >19.73%</td>
#       <td id="T_61ff8_row0_col9" class="data row0 col9" >33.79%</td>
#       <td id="T_61ff8_row0_col10" class="data row0 col10" >29.22%</td>
#       <td id="T_61ff8_row0_col11" class="data row0 col11" >39.58%</td>
#       <td id="T_61ff8_row0_col12" class="data row0 col12" >26.05%</td>
#     </tr>
#     <tr>
#       <th id="T_61ff8_level0_row1" class="row_heading level0 row1" >006400.KS</th>
#       <td id="T_61ff8_row1_col0" class="data row1 col0" >11.90%</td>
#       <td id="T_61ff8_row1_col1" class="data row1 col1" >12.00%</td>
#       <td id="T_61ff8_row1_col2" class="data row1 col2" >11.76%</td>
#       <td id="T_61ff8_row1_col3" class="data row1 col3" >11.60%</td>
#       <td id="T_61ff8_row1_col4" class="data row1 col4" >11.75%</td>
#       <td id="T_61ff8_row1_col5" class="data row1 col5" >13.40%</td>
#       <td id="T_61ff8_row1_col6" class="data row1 col6" >15.76%</td>
#       <td id="T_61ff8_row1_col7" class="data row1 col7" >25.95%</td>
#       <td id="T_61ff8_row1_col8" class="data row1 col8" >0.71%</td>
#       <td id="T_61ff8_row1_col9" class="data row1 col9" >10.02%</td>
#       <td id="T_61ff8_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_61ff8_row1_col11" class="data row1 col11" >0.24%</td>
#       <td id="T_61ff8_row1_col12" class="data row1 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_61ff8_level0_row2" class="row_heading level0 row2" >042700.KS</th>
#       <td id="T_61ff8_row2_col0" class="data row2 col0" >5.49%</td>
#       <td id="T_61ff8_row2_col1" class="data row2 col1" >6.54%</td>
#       <td id="T_61ff8_row2_col2" class="data row2 col2" >4.59%</td>
#       <td id="T_61ff8_row2_col3" class="data row2 col3" >6.27%</td>
#       <td id="T_61ff8_row2_col4" class="data row2 col4" >4.52%</td>
#       <td id="T_61ff8_row2_col5" class="data row2 col5" >0.63%</td>
#       <td id="T_61ff8_row2_col6" class="data row2 col6" >1.29%</td>
#       <td id="T_61ff8_row2_col7" class="data row2 col7" >2.92%</td>
#       <td id="T_61ff8_row2_col8" class="data row2 col8" >0.00%</td>
#       <td id="T_61ff8_row2_col9" class="data row2 col9" >0.00%</td>
#       <td id="T_61ff8_row2_col10" class="data row2 col10" >0.00%</td>
#       <td id="T_61ff8_row2_col11" class="data row2 col11" >0.00%</td>
#       <td id="T_61ff8_row2_col12" class="data row2 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_61ff8_level0_row3" class="row_heading level0 row3" >VZ</th>
#       <td id="T_61ff8_row3_col0" class="data row3 col0" >49.77%</td>
#       <td id="T_61ff8_row3_col1" class="data row3 col1" >50.48%</td>
#       <td id="T_61ff8_row3_col2" class="data row3 col2" >51.86%</td>
#       <td id="T_61ff8_row3_col3" class="data row3 col3" >51.14%</td>
#       <td id="T_61ff8_row3_col4" class="data row3 col4" >51.92%</td>
#       <td id="T_61ff8_row3_col5" class="data row3 col5" >49.91%</td>
#       <td id="T_61ff8_row3_col6" class="data row3 col6" >50.77%</td>
#       <td id="T_61ff8_row3_col7" class="data row3 col7" >56.16%</td>
#       <td id="T_61ff8_row3_col8" class="data row3 col8" >79.55%</td>
#       <td id="T_61ff8_row3_col9" class="data row3 col9" >56.19%</td>
#       <td id="T_61ff8_row3_col10" class="data row3 col10" >70.78%</td>
#       <td id="T_61ff8_row3_col11" class="data row3 col11" >60.18%</td>
#       <td id="T_61ff8_row3_col12" class="data row3 col12" >73.95%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
